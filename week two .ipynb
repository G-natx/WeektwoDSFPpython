# %%
##FUNCTIONS The are blocks ofcode that can be reused in multiple scenerios, there are inbuilt functions, 
###functions can be also be created, the functions should meet a need, 
##the function should have a nne that reflects the fuctions it is meant to carry out.
## building fuctiins give me the ability of rewriting my codes

# %%
# dir(--builtins--) is used tyo call out in built functions.

# %%
print("Hello ALL!!")
# Out:
# Hello ALL!!

# %%
def greeting ():
    return "Hello ALL!!"

# %%
# every function starts with a "def" which means definition, ()" countains what the functions should return, it is called a parameter 
#: this implies that we are noot done with the code
# "return"  is a command on what the function should return.

# %%
greeting()
# Out:
# Hello ALL!!

# %%
def greeting (name):
    """
    this function was developed by Grace Gado, it is meant to greet the user. But remeber to pass in the name of the person

    """
    return f'Hello {name}!!'

# %%
greeting('Ndip')
# Out:
# 'Hello Ndip!!'

# %%
#  help()" helps us to find out what a function does.

# %%
help (greeting)
# Out:
# Help on function greeting in module __main__:
#
# greeting(name)
#     this function was developed by Grace Gado, it is meant to greet the user. But remeber to pass in the name of the person

# %%
def pie():
    return(3.142)

# %%
pie()
# Out:
# 3.142

# %%
def area_of_circle():
    return(3.142)*r**2

# %%
r=5 
area_of_circle()
# Out:
# 78.55

# %%
def get_info(*args, **kwargs):
    print(args)
    print(kwargs)

# %%
get_info ("Gee", age = 30)
# Out:
# ('Gee',)
# {'age': 30}

# %%
#create a calculator that lets a user multiply or divide two numbers a, b.

# %%
print (calc (2, 5,'*'))
# Out:
# 10

# %%
def calc(x, y, op):
    if op == '*':
        return x * y
    elif op == '/':
        return x / y

# %%
# write a function that can take in a string and return the words in a string
string = 'simple is better than complex.'

# %%
string = 'simple is better than complex'
   string.split()
# Out:
#   Cell In[28], line 2
#     string.split()
#     ^
# IndentationError: unexpected indent

# %%
len(string)
# Out:
# 29

# %%
def count_str(string):
    string = input ()
    return len (string.split())
