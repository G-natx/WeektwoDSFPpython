# %%
#importing a txt file: * create a txt file using your system notepad,then save it on the same domain with your 
#jupyter notebook then open a new notebook and then import the file by typing in f = open ("content.txt", "r")

# %%
f = open ("content.txt", "r")
print(f.read())
for line in f:
    print(line)
# Out:
# Munirat
# Adnan
# Cohen
# Caris
# Habib
# Amaka
# Outlier

# %%
print(dir(f))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
f = open ("content.txt", "a")
f.write("Mubby")
f.close()

# %%
f = open ("content.txt")
f.read()
# Out:
# 'Munirat\nAdnan\nCohen\nCaris\nHabib\nAmaka\nOutlierMubby'

# %%
f = open ("content.txt", "r")
print(f.read())
# Out:
# Munirat
# Adnan
# Cohen
# Caris
# Habib
# Amaka
# OutlierMubby

# %%
#Exception Handling
#try: runs the risky code that might cause an error.
#except: catches and handles the error if one occurs.
#else: Executes only if no exception occurs intry
#finally:Runs regardless of what happens useful for cleanup tasks like closing files.

# %%
filename = 'alice.txt'
try:
    f = open(filename, 'r')
except FileNotFoundError:
    print('the file not found')
# Out:
# the file not found

# %%
try:
    print(name)
except NameError:
    print('name not defined')
# Out:
# name not defined

# %%
try:
    5/0
except ZeroDivisionError:
    print("can't Divide by Zero")
# Out:
# can't Divide by Zero

# %%
#write a function that permits takes from the user a file name that caters for a situation where the user enters 
#a wrong file name if so it should not break, it should print the content of the file out.

# %%
def read_file():
    filename = input("User file name: ")

    try:
        with open(filename, "r") as f:
            print(f.read())
    except FileNotFoundError:
        print("file not found. check the file info")
    except Exception as e:
        print("oops file not found:", e)

read_file()
# Out:
# User file name:  mubby
# file not found. check the file info

# %%
#this is a funtion that allows for division

# %%
while True:
    first_number = input("\nfirst number: ")
    if first_number == 'q':
         break 
    second_number = input ("Second number:")
    if second_number == 'q':
        break
    try:
        answer = int(first_number) / int(second_number)
    except ZeroDivisionError:
        print("You can't divide by 0!")
    else:
        print(answer)

# %%
while True:
    first_number = input("\nfirst number: ")
    if first_number == 'q':
         break 
    second_number = input ("Second number:")
    if second_number == 'q':
        break
    try:
        answer = int(first_number) / int(second_number)
    except Exception as e:
        print(e)
    else:
        print(answer)
